# %% [markdown]
# # Steps 2–3: Screening Eligibility, Test Assignment & Results
#
# This notebook covers the **decision layer** — the logic that runs immediately after a patient is seen by a provider and determines whether they should be screened, with which test, and what the result is.
#
# ## What this notebook covers
#
# **Step 2 — Eligibility & Test Assignment**
#
# Not every patient who walks into a clinic should receive every cancer screen. USPSTF guidelines define precise eligibility criteria:
# - Cervical: women aged 21–65 with a cervix
# - Lung: adults aged 50–80 with ≥20 pack-years of smoking history, currently smoking or quit within 15 years
#
# Once a patient is deemed eligible, the appropriate test modality is assigned:
# - Cervical, age 21–29: cytology (Pap smear) only
# - Cervical, age 30–65: cytology every 3 years *or* HPV-alone every 5 years
# - Lung: low-dose CT (LDCT)
#
# **Step 3 — Result Draws**
#
# Results are drawn stochastically from probability tables in `config.py`. Cervical cytology returns one of five Bethesda System categories (NORMAL through HSIL); HPV-alone returns binary (HPV_NEGATIVE / HPV_POSITIVE); lung returns a Lung-RADS v2022 category. Risk factors (HPV positivity, prior CIN) adjust the probabilities upward for abnormal categories.
#
# All probability values are **PLACEHOLDERS** — replace with NYP EHR-derived rates before using for planning.
#
# ---
# All logic lives in `screening.py`. This notebook demonstrates and validates each component individually, then runs a smoke test with 30 simulated patients.

# %%
import sys, random
sys.path.insert(0, '../src')   # add src/ so we can import local .py modules

import config as cfg
import matplotlib.pyplot as plt
from collections import Counter, defaultdict

from patient import Patient
from population import sample_patient          # generates synthetic patients
from metrics import initialize_metrics, record_screening
from screening import (
    get_eligible_screenings,      # returns list of cancers a patient qualifies for
    days_until_eligible,          # days until eligible, or -1 if permanently ineligible
    is_due_for_screening,         # checks if enough time has passed since last screen
    get_cervical_age_stratum,     # maps age to 'young' / 'middle' / 'older'
    assign_screening_test,        # picks the specific test (cytology, hpv_alone, ldct)
    draw_cervical_result,         # draws a Pap or HPV-alone result
    draw_lung_rads_result,        # draws a Lung-RADS category
    run_screening_step,           # full end-to-end screening event for one cancer
)

random.seed(cfg.RANDOM_SEED)
print('Imports OK')
# Out:
# Imports OK

# %% [markdown]
# ## Eligibility Checks
#
# Before any screening can happen, the patient must meet the clinical criteria for that cancer type. Getting eligibility right matters for two reasons:
# 1. **Clinical accuracy** — screening an ineligible patient (e.g. a 20-year-old for cervical cancer) wastes resources and produces no benefit.
# 2. **LTFU routing** — ineligible patients are not lost to follow-up; they either need to *return later* (e.g. turn 21) or are *permanently out of scope* (e.g. hysterectomy). The simulation must distinguish these two cases to route patients correctly.
#
# `get_eligible_screenings(patient)` loops over all cancers in `ACTIVE_CANCERS` and returns only those where the patient passes the eligibility function. The eligibility functions (`is_eligible_cervical`, `is_eligible_lung`) read directly from `config.ELIGIBILITY` so criteria can be tuned without touching the logic code.
#
# The test cases below exercise each branch of the eligibility logic to confirm the correct patients are included and excluded.

# %%
# We define a list of (label, age, has_cervix, smoker, pack_years, bmi) tuples.
# Each tuple represents a patient scenario designed to exercise a specific branch
# of the eligibility logic — e.g., the "no cervix" branch, the "too young" branch, etc.
cases = [
    # (label,                           age,  has_cervix, smoker, pack_years, bmi)
    ('Age 25, with cervix, non-smoker',  25,  True,  False, 0,  25),  # cervical only
    ('Age 45, with cervix, smoker 25pk', 45,  True,  True,  25, 25),  # cervical only (too young for lung)
    ('Age 45, no cervix',                45,  False, False, 0,  25),  # neither — no cervix, not a smoker
    ('Age 55, smoker 25pk',              55,  True,  True,  25, 25),  # both cervical and lung
    ('Age 68, BMI 17',                   68,  True,  False, 0,  17),  # neither — aged out of cervical, never smoked
    ('Age 70, all eligible',             70,  True,  True,  25, 25),  # lung only (cervical ends at 65)
    ('Age 20, below all thresholds',     20,  True,  False, 0,  25),  # neither — too young
]

print(f'{"Label":<35}  {"Eligible for"}')
print('-' * 70)
for label, age, has_cervix, smoker, pack_years, bmi in cases:
    # sample_patient() creates a patient with random demographics.
    # We then overwrite the specific fields we want to control for this test case,
    # leaving everything else as a realistic random value.
    p = sample_patient(0, 0, 'pcp', 'outpatient')
    p.age, p.has_cervix, p.smoker = age, has_cervix, smoker
    p.pack_years, p.bmi = pack_years, bmi

    # get_eligible_screenings() loops over all active cancer types,
    # runs each one's eligibility check function, and returns only those that pass
    eligible = get_eligible_screenings(p)
    print(f'{label:<35}  {", ".join(eligible) if eligible else "(none)"}')
# Out:
# Label                                Eligible for
# ----------------------------------------------------------------------
# Age 25, with cervix, non-smoker      cervical
# Age 45, with cervix, smoker 25pk     cervical
# Age 45, no cervix                    (none)
# Age 55, smoker 25pk                  cervical, lung
# Age 68, BMI 17                       (none)
# Age 70, all eligible                 lung
# Age 20, below all thresholds         (none)

# %% [markdown]
# ## Test Assignment
#
# Given that a patient is eligible, which specific test should they receive? This is governed by USPSTF and ASCCP guidelines:
#
# - **Cervical, age 21–29**: cytology (Pap smear) only. HPV testing is not recommended under 30 because HPV infections are common and mostly transient in this age group — testing would cause high false-positive rates.
# - **Cervical, age 30–65**: either cytology every 3 years *or* HPV-alone every 5 years (both are Grade A recommendations). The simulation randomly picks between these two options at each visit.
# - **Lung**: always LDCT (low-dose CT), regardless of age within the eligible range.
#
# `assign_screening_test` first classifies the patient into an age stratum (`get_cervical_age_stratum`), then looks up the available tests for that stratum in `config.SCREENING_TESTS`. For the middle stratum, it randomly picks one from the list — this is how the model reflects that different providers and patients choose different options.

# %%
# For each age, we:
#   1. Create a patient and set their age
#   2. Call get_cervical_age_stratum() to see which config bucket they fall into
#   3. Call assign_screening_test() which looks up the available tests for that stratum
#      and randomly picks one (for the middle stratum, this is cytology or hpv_alone)
# Age 22   → young stratum  → cytology only (HPV testing not recommended under 30)
# Age 35/50 → middle stratum → cytology OR hpv_alone (randomly chosen each visit)
# Age 66   → older stratum  → ineligible (no routine screening after 65)
ages = [22, 35, 50, 66]
print(f'{"Age":<6}  {"Stratum":<10}  {"Assigned test"}')
print('-' * 40)
for age in ages:
    p = sample_patient(0, 0, 'gynecologist', 'outpatient')
    p.age, p.has_cervix = age, True
    stratum = get_cervical_age_stratum(age)   # classifies age into young/middle/older
    test    = assign_screening_test(p, 'cervical')  # picks test from options for that stratum
    print(f'{age:<6}  {stratum:<10}  {test}')
# Out:
# Age     Stratum     Assigned test
# ----------------------------------------
# 22      young       cytology
# 35      middle      cytology
# 50      middle      cytology
# 66      older       ineligible

# %% [markdown]
# ## Cervical Result Distribution
#
# Screening results are drawn stochastically from probability tables in `config.py`. The tables are stratified by age and test type, reflecting the fact that younger women have different base rates for abnormality than older women, and that HPV-alone vs. cytology tests report different result categories.
#
# We validate the result draws here by running many trials and comparing the observed frequency distribution to the configured probabilities. In a correctly implemented model, observed ≈ expected (within Monte Carlo noise). Systematic divergence would indicate a bug in the draw logic.
#
# **Cervical cytology** (Pap smear) uses the Bethesda System: NORMAL → ASCUS → LSIL → ASC-H → HSIL, in order of increasing severity.
# **HPV-alone** test is binary: HPV_NEGATIVE or HPV_POSITIVE. A positive result does not report a Pap category — it only indicates the presence of high-risk HPV and triggers further triage.

# %%
N = 5_000

# Build one reusable patient template — no risk factors so we're testing the base rates
p_template = sample_patient(0, 0, 'gynecologist', 'outpatient')
p_template.age, p_template.has_cervix = 42, True
p_template.hpv_positive, p_template.prior_cin = False, None

# ── Cytology (Pap smear) ──────────────────────────────────────────────────────
# draw_cervical_result() uses the patient's age stratum and risk factors to look up
# the right probability table from config, then does a weighted random draw.
# We call it N=5,000 times and count how often each category appears,
# then compare to the expected config probabilities to verify correctness.
results_cyto = [draw_cervical_result(p_template, 'cytology') for _ in range(N)]
counts_cyto  = Counter(results_cyto)

print(f'Cytology result distribution (n={N:,}, age=42):')
for cat in ['NORMAL', 'ASCUS', 'LSIL', 'ASC-H', 'HSIL']:
    cnt      = counts_cyto.get(cat, 0)
    expected = cfg.CERVICAL_RESULT_PROBS['middle_cytology'].get(cat, 0)
    print(f'  {cat:<30} observed={cnt/N*100:5.1f}%  expected={expected*100:5.1f}%')

print()

# ── HPV-alone ─────────────────────────────────────────────────────────────────
# Same approach but for the HPV-alone test — this uses a different probability table
# (middle_hpv) and returns only two categories instead of five.
# HPV_POSITIVE routes the patient into the colposcopy/1-yr-repeat pathway.
results_hpv = [draw_cervical_result(p_template, 'hpv_alone') for _ in range(N)]
counts_hpv  = Counter(results_hpv)

print(f'HPV-alone result distribution (n={N:,}, age=42):')
for cat in ['HPV_NEGATIVE', 'HPV_POSITIVE']:
    cnt      = counts_hpv.get(cat, 0)
    expected = cfg.CERVICAL_RESULT_PROBS['middle_hpv'].get(cat, 0)
    print(f'  {cat:<30} observed={cnt/N*100:5.1f}%  expected={expected*100:5.1f}%')
# Out:
# Cytology result distribution (n=5,000, age=42):
#   NORMAL                         observed= 91.3%  expected= 91.0%
#   ASCUS                          observed=  3.0%  expected=  3.5%
#   LSIL                           observed=  3.1%  expected=  3.0%
#   ASC-H                          observed=  1.4%  expected=  1.5%
#   HSIL                           observed=  1.2%  expected=  1.0%
#
# HPV-alone result distribution (n=5,000, age=42):
#   HPV_NEGATIVE                   observed= 88.0%  expected= 88.0%
#   HPV_POSITIVE                   observed= 12.0%  expected= 12.0%

# %% [markdown]
# ## Cervical Result Distributions by Age Stratum
#
# USPSTF guidelines stratify cervical screening by age because the expected abnormality rate differs between young and middle-aged women. Younger women (21–29) tend to have higher rates of low-grade changes (ASCUS, LSIL) that often resolve without treatment, while the rate of high-grade lesions (ASC-H, HSIL) is lower but more clinically significant.
#
# The charts below compare simulated results against the configured expected rates. Both bars for each category should be close in height — any large discrepancy indicates that the probability table or draw function has an error.

# %%
N = 10_000

# Each tuple defines one subplot: (display label, patient age, test type, config key)
# The config key tells us which probability table to use for the "expected" bars
strata_info = [
    ('young (age 25)',   25, 'cytology', 'young'),
    ('middle (age 42)', 42, 'cytology', 'middle_cytology'),
]

# The five standard Bethesda System cytology categories, in order of severity
categories = ['NORMAL', 'ASCUS', 'LSIL', 'ASC-H', 'HSIL']

fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharey=False)

for ax, (label, age, test, cfg_key) in zip(axes, strata_info):
    # Build a no-risk-factor patient at the target age
    pt = sample_patient(0, 0, 'gynecologist', 'outpatient')
    pt.age, pt.has_cervix, pt.hpv_positive, pt.prior_cin = age, True, False, None

    # Run N draws and count how often each category came up
    results = [draw_cervical_result(pt, test) for _ in range(N)]
    counts  = Counter(results)

    # Convert counts to % for the observed bars; look up config values for expected bars
    obs = [counts.get(c, 0) / N * 100 for c in categories]
    exp = [cfg.CERVICAL_RESULT_PROBS[cfg_key].get(c, 0) * 100 for c in categories]

    # Plot observed and expected side by side for easy comparison
    # Offset by ±0.2 so the two sets of bars don't overlap
    x = range(len(categories))
    ax.bar([i - 0.2 for i in x], obs, width=0.4, label='Observed', alpha=0.8)
    ax.bar([i + 0.2 for i in x], exp, width=0.4, label='Expected', alpha=0.8)
    ax.set_xticks(list(x))
    ax.set_xticklabels(categories, rotation=30)
    ax.set_ylabel('Frequency (%)')
    ax.set_title(f'Cytology — {label}')
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Risk Factor Effect on Cytology Results
#
# Two patient-level risk factors increase the probability of an abnormal cytology result:
# - **HPV positivity** — being a known high-risk HPV carrier inflates all abnormal cytology categories by 1.5× (a configurable risk multiplier).
# - **Prior high-grade CIN (CIN2/CIN3)** — a history of high-grade cervical dysplasia further inflates ASC-H and HSIL by 1.8×. This models the recurrence risk after prior treatment.
#
# When both factors are present, both adjustments apply in sequence, compounding the effect.
#
# The chart below shows the overall abnormal rate (any non-NORMAL result) across four risk profiles. The gradient from baseline to HPV+ & Prior CIN3 validates that the risk adjustment logic in `_adjust_probs()` is working correctly.

# %%
N = 10_000
# Any result that is not NORMAL counts as abnormal (requires follow-up)
abnormal_cats = ['ASCUS', 'LSIL', 'ASC-H', 'HSIL']

# Four combinations of risk factors — same base patient (age 42) across all four
# so the only variable changing is the risk flag(s)
groups = [
    ('No risk factors',   False, None),    # baseline
    ('HPV positive',      True,  None),    # HPV alone inflates all abnormal categories 1.5×
    ('Prior CIN2/3',      False, 'CIN2'),  # prior high-grade CIN inflates ASC-H/HSIL 1.8×
    ('HPV+ & Prior CIN3', True,  'CIN3'),  # both adjustments applied multiplicatively
]

labels, abnormal_rates = [], []
for label, hpv_pos, prior_cin in groups:
    pt = sample_patient(0, 0, 'gynecologist', 'outpatient')
    pt.age, pt.has_cervix = 42, True
    pt.hpv_positive, pt.prior_cin = hpv_pos, prior_cin

    # Draw N results, then count what fraction were abnormal (any non-NORMAL category)
    results = [draw_cervical_result(pt, 'cytology') for _ in range(N)]
    rate    = sum(1 for r in results if r in abnormal_cats) / N * 100
    labels.append(label)
    abnormal_rates.append(rate)

fig, ax = plt.subplots(figsize=(8, 4))
ax.bar(labels, abnormal_rates, color=['steelblue', 'tomato', 'orange', 'firebrick'])
ax.set_ylabel('Any abnormal result (%)')
ax.set_title('Risk factor effect on cervical cytology abnormality rate')
ax.set_ylim(0, max(abnormal_rates) * 1.3)
# Label each bar with its exact percentage value
for i, v in enumerate(abnormal_rates):
    ax.text(i, v + 0.3, f'{v:.1f}%', ha='center', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Lung-RADS Distribution
#
# After a low-dose CT scan, the radiologist assigns a Lung-RADS v2022 category that determines the next clinical step:
# - **RADS 0** — incomplete scan, must be repeated in 1–3 months
# - **RADS 1/2** — negative or benign appearance, routine 12-month repeat
# - **RADS 3** — probably benign, 6-month repeat to confirm stability
# - **RADS 4A/4B/4X** — suspicious finding, biopsy pathway initiated
#
# The chart validates that `draw_lung_rads_result()` matches the configured `LUNG_RADS_PROBS` table. In a real calibration step, this table would be fit to NYP's historical LDCT scan volume and RADS distribution data.

# %%
N = 10_000
# draw_lung_rads_result() does a single weighted random draw from LUNG_RADS_PROBS.
# We call it N times and count results, then compare to the config weights.
rads_results = [draw_lung_rads_result() for _ in range(N)]
rads_counts  = Counter(rads_results)
categories   = list(cfg.LUNG_RADS_PROBS.keys())  # keys are ordered as defined in config

# Compute observed % from our simulation and expected % from config
obs = [rads_counts.get(c, 0) / N * 100 for c in categories]
exp = [cfg.LUNG_RADS_PROBS[c] * 100 for c in categories]

# Side-by-side bars for each RADS category — observed should closely match expected
fig, ax = plt.subplots(figsize=(9, 4))
x = range(len(categories))
ax.bar([i - 0.2 for i in x], obs, width=0.4, label='Observed', alpha=0.8)
ax.bar([i + 0.2 for i in x], exp, width=0.4, label='Expected', alpha=0.8)
ax.set_xticks(list(x))
ax.set_xticklabels(categories)
ax.set_ylabel('Frequency (%)')
ax.set_title(f'Lung-RADS distribution (n={N:,})')
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Smoke Test — Run 30 Patients Through Screening
#
# This is an end-to-end integration test that runs the complete screening pipeline for a small cohort. It exercises every component that has been demonstrated individually above: eligibility checking, test assignment, result draws, and the three-way routing for ineligible patients.
#
# The three-way eligibility outcome is a key design feature:
# - **Eligible and screened** — patient receives their test, result is drawn, metrics are recorded.
# - **Not yet eligible (days_until_eligible > 0)** — patient is ineligible today (too young, not enough pack-years) but will become eligible in the future. In the full runner, this patient would be rescheduled for a return visit.
# - **Permanently ineligible (days_until_eligible = -1)** — patient can never qualify (no cervix, aged out of the window, never smoked). No reschedule is needed; they exit silently.
#
# The event log at the end traces every step for a single patient, verifying that the full chain from eligibility check through result draw is being logged correctly.

# %%
random.seed(42)
DAY        = 0
N_PATIENTS = 30
metrics    = initialize_metrics()

# Generate N synthetic patients for this simulated day
patients      = [sample_patient(i, DAY, 'gynecologist', 'outpatient') for i in range(N_PATIENTS)]
screening_log = defaultdict(list)  # accumulates results keyed by cancer type or eligibility bucket

for p in patients:
    metrics['n_patients'] += 1

    # Step 1: ask which cancers this patient is currently eligible for
    eligible = get_eligible_screenings(p)

    if not eligible:
        # Not eligible for any cancer right now — figure out whether that's temporary or permanent.
        # days_until_eligible() returns:
        #   >0  → patient will qualify in N days (e.g. turns 21 next year)
        #   -1  → patient can never qualify (no cervix, aged out, never smoked, etc.)
        soonest = -1
        for cancer in cfg.ACTIVE_CANCERS:
            d = days_until_eligible(p, cancer)
            if d > 0 and (soonest < 0 or d < soonest):
                soonest = d  # keep track of the earliest date any cancer becomes eligible

        if soonest > 0:
            # Will become eligible — log for return visit scheduling
            screening_log['not_yet_eligible'].append(f'return in {soonest}d')
        else:
            # Permanently ineligible — patient exits silently with no reschedule
            screening_log['permanently_ineligible'].append('exit')

        metrics['n_unscreened'] += 1
        continue  # move on to the next patient

    metrics['n_eligible_any'] += 1

    # Step 2: for each eligible cancer, run the full screening step.
    # run_screening_step() handles the interval check, test assignment, result draw,
    # and (for lung) the pre-LDCT referral/scheduling checks. Returns None if skipped.
    for cancer in eligible:
        result = run_screening_step(p, cancer, DAY, metrics)
        if result:
            # Explicitly call record_screening here since we bypassed the runner
            record_screening(metrics, p, cancer, result)
            screening_log[cancer].append(result)

# ── Summary ───────────────────────────────────────────────────────────────────
print(f'Results across {N_PATIENTS} patients:\n')
for key, results in sorted(screening_log.items()):
    cnt = Counter(results)
    print(f'  {key}:')
    for r, c in sorted(cnt.items()):
        print(f'    {r:<35} {c}')

print(f'\n  Total seen:                       {metrics["n_patients"]}')
print(f'  Eligible for any screen:          {metrics["n_eligible_any"]}')
print(f'  Not yet / permanently ineligible: {metrics["n_unscreened"]}')
print(f'  Cervical screened:                {metrics["n_screened"]["cervical"]}')
print(f'  Lung screened:                    {metrics["n_screened"]["lung"]}')

# Print the full event log for the first patient to verify the step-by-step trace
print('\n── Sample patient trace ──')
patients[0].print_history()
# Out:
# Results across 30 patients:
#
#   cervical:
#     ASCUS                               1
#     HPV_NEGATIVE                        11
#     HPV_POSITIVE                        1
#     NORMAL                              9
#   lung:
#     RADS_2                              2
#   permanently_ineligible:
#     exit                                6
#
#   Total seen:                       30
#   Eligible for any screen:          24
#   Not yet / permanently ineligible: 6
#   Cervical screened:                22
#   Lung screened:                    2
#
# ── Sample patient trace ──
#
# ── Patient 0 | age=50 | destination=gynecologist ──
#   Day     0: SCREEN cervical via hpv_alone
#   Day     0: RESULT cervical: HPV_POSITIVE
